# %%
import utilities

# %%
dg = utilities.DataGenerator(6,0.1,0.1,'hudson',[],10,42)

# %%
data = dg.run_simulation()

# %%
new_data = []
for d in data: new_data.append(d)

# %%
for f in new_data:
    for d in f.trees():
        print(d.draw(format="unicode"))
# Out:
#      10
#    ┏━━┻━━┓
#    ┃     9
#    ┃    ┏┻┓
#    8    ┃ ┃
#  ┏━┻━┓  ┃ ┃
#  ┃   7  ┃ ┃
#  ┃  ┏┻┓ ┃ ┃
#  6  ┃ ┃ ┃ ┃
# ┏┻┓ ┃ ┃ ┃ ┃
# 0 5 2 3 1 4
#
#     11
#   ┏━━┻━━┓
#   ┃    10
#   ┃   ┏━┻┓
#   9   ┃  ┃
# ┏━┻┓  ┃  ┃
# ┃  8  ┃  ┃
# ┃ ┏┻┓ ┃  ┃
# ┃ ┃ ┃ ┃  6
# ┃ ┃ ┃ ┃ ┏┻┓
# 2 1 3 5 0 4
#
#      11
#    ┏━━┻━━┓
#    9     ┃
#  ┏━┻━┓   ┃
#  8   ┃   ┃
# ┏┻┓  ┃   ┃
# ┃ ┃  7   ┃
# ┃ ┃ ┏┻┓  ┃
# ┃ ┃ ┃ ┃  6
# ┃ ┃ ┃ ┃ ┏┻┓
# 1 3 2 5 0 4
#
#     10
#   ┏━━┻━━┓
#   ┃     9
#   ┃   ┏━┻┓
#   ┃   ┃  8
#   ┃   ┃ ┏┻┓
#   7   ┃ ┃ ┃
# ┏━┻┓  ┃ ┃ ┃
# ┃  6  ┃ ┃ ┃
# ┃ ┏┻┓ ┃ ┃ ┃
# 3 0 4 1 2 5
#
#    10
#  ┏━━┻━━┓
#  ┃     9
#  ┃   ┏━┻━┓
#  ┃   ┃   8
#  ┃   ┃  ┏┻┓
#  7   ┃  ┃ ┃
# ┏┻┓  ┃  ┃ ┃
# ┃ ┃  6  ┃ ┃
# ┃ ┃ ┏┻┓ ┃ ┃
# 1 4 3 5 0 2
#
#      10
#   ┏━━━┻━━┓
#   ┃      9
#   ┃     ┏┻┓
#   8     ┃ ┃
# ┏━┻━┓   ┃ ┃
# ┃   7   ┃ ┃
# ┃ ┏━┻┓  ┃ ┃
# ┃ ┃  6  ┃ ┃
# ┃ ┃ ┏┻┓ ┃ ┃
# 1 5 3 4 0 2
#
#   10
# ┏━━┻━━┓
# ┃     9
# ┃  ┏━━┻━┓
# ┃  ┃    8
# ┃  ┃  ┏━┻┓
# ┃  7  ┃  ┃
# ┃ ┏┻┓ ┃  ┃
# ┃ ┃ ┃ ┃  6
# ┃ ┃ ┃ ┃ ┏┻┓
# ...
